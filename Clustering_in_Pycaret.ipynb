# %% [markdown]
# <a href="https://colab.research.google.com/github/SinSham/Clustering-in-Pycaret/blob/main/Clustering_in_Pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ucimlrepo

# %%
# !pip install pycaret[full] &> /dev/null
print("Pycaret installed successfully")
# Out:
# Pycaret installed successfully

# %%
from pycaret.datasets import get_data
dataSets = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dataSets = dataSets.drop(columns = ['species'])

# %%
from pycaret.clustering import *
ClusteringParameters = setup(dataSets)
# Out:
# <style type="text/css">
# #T_e61b1_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e61b1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e61b1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e61b1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e61b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e61b1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e61b1_row0_col1" class="data row0 col1" >3645</td>
#     </tr>
#     <tr>
#       <th id="T_e61b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e61b1_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e61b1_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
# ...

# %%
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
# kmodes                   K-Modes Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# ...

# %%
print("K-Means Clustering")
KMeanClusteringModel = create_model('kmeans')
print("K-Modes Clustering")
KModesClusteringModel = create_model('kmodes')
print("Affinity Propagation")
AffPropagationModel = create_model('ap')
print("Mean Shift Clustering")
MeanShiftModel = create_model('meanshift')
print("Spectral Clustering")
SpectralClusteringModel = create_model('sc')
print("Agglomerative Clustering")
AggloClusteringModel = create_model('hclust')
print("Density-Based Spatial Clustering")
DBScanClusteringModel = create_model('dbscan')
print("OPTICS Clustering	")
OpticsClusteringModel = create_model('optics')
print("Birch Clustering")
BirchClusteringModel = create_model('birch')
# Out:
# K-Means Clustering
# <style type="text/css">
# </style>
# <table id="T_27828" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27828_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_27828_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_27828_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_27828_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_27828_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_27828_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27828_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27828_row0_col0" class="data row0 col0" >0.4978</td>
#       <td id="T_27828_row0_col1" class="data row0 col1" >529.3983</td>
# ...

# %%
MeanShiftPrediction = assign_model(MeanShiftModel)
MeanShiftPrediction
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    Cluster
# 0             5.1          3.5           1.4          0.2  Cluster 1
# 1             4.9          3.0           1.4          0.2  Cluster 1
# 2             4.7          3.2           1.3          0.2  Cluster 1
# 3             4.6          3.1           1.5          0.2  Cluster 1
# 4             5.0          3.6           1.4          0.2  Cluster 1
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Cluster 0
# 146           6.3          2.5           5.0          1.9  Cluster 0
# 147           6.5          3.0           5.2          2.0  Cluster 0
# 148           6.2          3.4           5.4          2.3  Cluster 0
# 149           5.9          3.0           5.1          1.8  Cluster 0
#
# [150 rows x 5 columns]

# %%
plot_model(MeanShiftModel, plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(MeanShiftModel, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(MeanShiftModel, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Model Performance using "Normalization"

# %%
setup(data = dataSets, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('meanshift')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5cad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5cad_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e5cad_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e5cad_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e5cad_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e5cad_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e5cad_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5cad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5cad_row0_col0" class="data row0 col0" >0.5802</td>
#       <td id="T_e5cad_row0_col1" class="data row0 col1" >248.9035</td>
# ...

# %% [markdown]
# ## Model Performance using "Transformation"

# %%
setup(data = dataSets, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('meanshift')
# Out:
# <style type="text/css">
# </style>
# <table id="T_79d94" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79d94_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_79d94_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_79d94_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_79d94_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_79d94_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_79d94_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79d94_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79d94_row0_col0" class="data row0 col0" >0.7633</td>
#       <td id="T_79d94_row0_col1" class="data row0 col1" >762.9648</td>
# ...

# %% [markdown]
# ## Model Performance using "PCA"

# %%
setup(data = dataSets, pca = True, pca_method = 'linear', verbose=False)
x = create_model('meanshift')
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc202" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc202_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bc202_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bc202_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bc202_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bc202_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bc202_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc202_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc202_row0_col0" class="data row0 col0" >0.6855</td>
#       <td id="T_bc202_row0_col1" class="data row0 col1" >508.8823</td>
# ...

# %% [markdown]
# ## Model Performance using "Transformation" + "Normalization"

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('meanshift')
# Out:
# <style type="text/css">
# </style>
# <table id="T_44655" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44655_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_44655_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_44655_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_44655_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_44655_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_44655_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44655_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44655_row0_col0" class="data row0 col0" >0.5836</td>
#       <td id="T_44655_row0_col1" class="data row0 col1" >254.4470</td>
# ...

# %% [markdown]
# ## Model Performance using "Transformation" + "Normalization" + "PCA"

# %%
setup(data = dataSets, transformation = True, normalize = True, pca = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear', verbose=False)
x = create_model('meanshift')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c190" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c190_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9c190_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9c190_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9c190_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9c190_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9c190_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c190_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c190_row0_col0" class="data row0 col0" >0.5836</td>
#       <td id="T_9c190_row0_col1" class="data row0 col1" >254.4469</td>
# ...

# %% [markdown]
# ## Other Clustering Models

# %% [markdown]
# ## Model = K-Means

# %%
setup(data = dataSets, verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b73e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b73e9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b73e9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b73e9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b73e9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b73e9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b73e9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b73e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b73e9_row0_col0" class="data row0 col0" >0.4970</td>
#       <td id="T_b73e9_row0_col1" class="data row0 col1" >529.1257</td>
# ...

# %% [markdown]
# ## Model Performance using "Normalization"

# %%
setup(data = dataSets, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ae77" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ae77_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9ae77_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9ae77_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9ae77_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9ae77_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9ae77_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ae77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ae77_row0_col0" class="data row0 col0" >0.3905</td>
#       <td id="T_9ae77_row0_col1" class="data row0 col1" >206.0982</td>
# ...

# %%
setup(data = dataSets, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_fc08e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc08e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fc08e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fc08e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fc08e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fc08e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fc08e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc08e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc08e_row0_col0" class="data row0 col0" >0.4590</td>
#       <td id="T_fc08e_row0_col1" class="data row0 col1" >239.3419</td>
# ...

# %% [markdown]
# ## Model Performance using "Transformation"

# %%
setup(data = dataSets, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_278ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_278ea_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_278ea_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_278ea_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_278ea_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_278ea_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_278ea_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_278ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_278ea_row0_col0" class="data row0 col0" >0.6178</td>
#       <td id="T_278ea_row0_col1" class="data row0 col1" >1352.6687</td>
# ...

# %%
setup(data = dataSets, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_6e9cc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e9cc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6e9cc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6e9cc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6e9cc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6e9cc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6e9cc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e9cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e9cc_row0_col0" class="data row0 col0" >0.6548</td>
#       <td id="T_6e9cc_row0_col1" class="data row0 col1" >1167.4515</td>
# ...

# %% [markdown]
# ## Model Performance using "PCA"

# %%
setup(data = dataSets, pca = True, pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b15ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b15ed_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b15ed_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b15ed_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b15ed_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b15ed_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b15ed_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b15ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b15ed_row0_col0" class="data row0 col0" >0.4978</td>
#       <td id="T_b15ed_row0_col1" class="data row0 col1" >529.3983</td>
# ...

# %%
setup(data = dataSets, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_4f7a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f7a9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4f7a9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4f7a9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4f7a9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4f7a9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4f7a9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f7a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f7a9_row0_col0" class="data row0 col0" >0.5526</td>
#       <td id="T_4f7a9_row0_col1" class="data row0 col1" >560.4000</td>
# ...

# %% [markdown]
# ## Model Performance using "Transformation" + "Normalization"

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1bd83" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bd83_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1bd83_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1bd83_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1bd83_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1bd83_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1bd83_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bd83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bd83_row0_col0" class="data row0 col0" >0.4185</td>
#       <td id="T_1bd83_row0_col1" class="data row0 col1" >210.2697</td>
# ...

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e73f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e73f3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e73f3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e73f3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e73f3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e73f3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e73f3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e73f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e73f3_row0_col0" class="data row0 col0" >0.4575</td>
#       <td id="T_e73f3_row0_col1" class="data row0 col1" >242.9960</td>
# ...

# %% [markdown]
# ## Model Performance using "Transformation" + "Normalization" + "PCA"

# %%
setup(data = dataSets, transformation = True, normalize = True, pca = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b918" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b918_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6b918_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6b918_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6b918_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6b918_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6b918_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b918_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b918_row0_col0" class="data row0 col0" >0.4185</td>
#       <td id="T_6b918_row0_col1" class="data row0 col1" >210.2697</td>
# ...

# %%
setup(data = dataSets, transformation = True, normalize = True, pca = True,normalize_method = 'zscore',transformation_method = 'yeo-johnson',pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_b9749" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9749_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b9749_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b9749_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b9749_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b9749_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b9749_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9749_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9749_row0_col0" class="data row0 col0" >0.4575</td>
#       <td id="T_b9749_row0_col1" class="data row0 col1" >242.9960</td>
# ...

# %% [markdown]
# ## Model = Spectral Clustering

# %%
setup(data = dataSets, verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a0127" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0127_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a0127_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a0127_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a0127_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a0127_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a0127_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0127_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0127_row0_col0" class="data row0 col0" >0.4914</td>
#       <td id="T_a0127_row0_col1" class="data row0 col1" >466.6312</td>
# ...

# %% [markdown]
# ## Model Performance using "Normalization"

# %%
setup(data = dataSets, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1757" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1757_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d1757_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d1757_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d1757_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d1757_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d1757_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1757_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1757_row0_col0" class="data row0 col0" >0.1591</td>
#       <td id="T_d1757_row0_col1" class="data row0 col1" >55.3567</td>
# ...

# %%
setup(data = dataSets, normalize = True, verbose=False)

print("For Cluster = 3")
x = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x = create_model('sc', num_clusters = 5)

print("For Cluster = 6")
x = create_model('sc', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_43deb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43deb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_43deb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_43deb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_43deb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_43deb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_43deb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43deb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43deb_row0_col0" class="data row0 col0" >0.4619</td>
#       <td id="T_43deb_row0_col1" class="data row0 col1" >234.3256</td>
# ...

# %% [markdown]
# ## Model Performance using "Transformation"

# %%
setup(data = dataSets, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a111f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a111f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a111f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a111f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a111f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a111f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a111f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a111f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a111f_row0_col0" class="data row0 col0" >0.5521</td>
#       <td id="T_a111f_row0_col1" class="data row0 col1" >947.7497</td>
# ...

# %%
setup(data = dataSets, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x = create_model('sc', num_clusters = 5)

print("For Cluster = 6")
x = create_model('sc', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_9cecf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cecf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9cecf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9cecf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9cecf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9cecf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9cecf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cecf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9cecf_row0_col0" class="data row0 col0" >0.6555</td>
#       <td id="T_9cecf_row0_col1" class="data row0 col1" >1121.6756</td>
# ...

# %% [markdown]
# ## Model Performance using "PCA"

# %%
setup(data = dataSets, pca = True, pca_method = 'linear', verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b3587" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3587_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b3587_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b3587_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b3587_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b3587_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b3587_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3587_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3587_row0_col0" class="data row0 col0" >0.4914</td>
#       <td id="T_b3587_row0_col1" class="data row0 col1" >466.6309</td>
# ...

# %%
setup(data = dataSets, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x = create_model('sc', num_clusters = 5)

print("For Cluster = 6")
x = create_model('sc', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a6bac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6bac_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a6bac_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a6bac_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a6bac_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a6bac_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a6bac_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6bac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6bac_row0_col0" class="data row0 col0" >0.5551</td>
#       <td id="T_a6bac_row0_col1" class="data row0 col1" >554.9067</td>
# ...

# %% [markdown]
# ## Model Performance using "Normalization" + "Transformation"

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_366e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_366e3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_366e3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_366e3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_366e3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_366e3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_366e3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_366e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_366e3_row0_col0" class="data row0 col0" >0.3885</td>
#       <td id="T_366e3_row0_col1" class="data row0 col1" >202.5138</td>
# ...

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x = create_model('sc', num_clusters = 5)

print("For Cluster = 6")
x = create_model('sc', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_1508d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1508d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1508d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1508d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1508d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1508d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1508d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1508d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1508d_row0_col0" class="data row0 col0" >0.4594</td>
#       <td id="T_1508d_row0_col1" class="data row0 col1" >240.8892</td>
# ...

# %% [markdown]
# ## Model Performance using "Normalization" + "Transformation" + "PCA"

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca = True, pca_method = 'linear', verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_799c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_799c0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_799c0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_799c0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_799c0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_799c0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_799c0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_799c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_799c0_row0_col0" class="data row0 col0" >0.3885</td>
#       <td id="T_799c0_row0_col1" class="data row0 col1" >202.5138</td>
# ...

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca=True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x = create_model('sc', num_clusters = 5)

print("For Cluster = 6")
x = create_model('sc', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_6a2c9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a2c9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6a2c9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6a2c9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6a2c9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6a2c9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6a2c9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a2c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a2c9_row0_col0" class="data row0 col0" >0.4594</td>
#       <td id="T_6a2c9_row0_col1" class="data row0 col1" >240.8892</td>
# ...

# %% [markdown]
# ## Model = Agglomerative Clustering

# %%
setup(data = dataSets, verbose=False)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_104b0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_104b0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_104b0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_104b0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_104b0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_104b0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_104b0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_104b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_104b0_row0_col0" class="data row0 col0" >0.4887</td>
#       <td id="T_104b0_row0_col1" class="data row0 col1" >513.7721</td>
# ...

# %% [markdown]
# ## Model Performance using "Normalization"

# %%
setup(data = dataSets, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e4ba" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e4ba_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6e4ba_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6e4ba_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6e4ba_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6e4ba_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6e4ba_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e4ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e4ba_row0_col0" class="data row0 col0" >0.3993</td>
#       <td id="T_6e4ba_row0_col1" class="data row0 col1" >198.7303</td>
# ...

# %%
setup(data = dataSets, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c090c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c090c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c090c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c090c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c090c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c090c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c090c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c090c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c090c_row0_col0" class="data row0 col0" >0.4455</td>
#       <td id="T_c090c_row0_col1" class="data row0 col1" >220.2605</td>
# ...

# %% [markdown]
# ## Model Performance using "Transformation"

# %%
setup(data = dataSets, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_def32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_def32_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_def32_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_def32_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_def32_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_def32_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_def32_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_def32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_def32_row0_col0" class="data row0 col0" >0.5885</td>
#       <td id="T_def32_row0_col1" class="data row0 col1" >1222.9414</td>
# ...

# %%
setup(data = dataSets, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0535c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0535c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0535c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0535c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0535c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0535c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0535c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0535c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0535c_row0_col0" class="data row0 col0" >0.6503</td>
#       <td id="T_0535c_row0_col1" class="data row0 col1" >1138.6493</td>
# ...

# %% [markdown]
# ## Model Performance using "PCA"

# %%
setup(data = dataSets, pca = True, pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_322ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_322ea_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_322ea_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_322ea_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_322ea_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_322ea_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_322ea_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_322ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_322ea_row0_col0" class="data row0 col0" >0.4887</td>
#       <td id="T_322ea_row0_col1" class="data row0 col1" >513.7722</td>
# ...

# %%
setup(data = dataSets, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_2f6af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f6af_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2f6af_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2f6af_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2f6af_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2f6af_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2f6af_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f6af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f6af_row0_col0" class="data row0 col0" >0.5541</td>
#       <td id="T_2f6af_row0_col1" class="data row0 col1" >556.8412</td>
# ...

# %% [markdown]
# ## Model Performance using "Normalization" + "Transformation"

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson',verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4a491" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a491_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4a491_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4a491_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4a491_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4a491_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4a491_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a491_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a491_row0_col0" class="data row0 col0" >0.4251</td>
#       <td id="T_4a491_row0_col1" class="data row0 col1" >200.0175</td>
# ...

# %%
setup(data = dataSets, normalize = True, normalize_method = 'zscore', transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_4d4fb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d4fb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4d4fb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4d4fb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4d4fb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4d4fb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4d4fb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d4fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d4fb_row0_col0" class="data row0 col0" >0.4462</td>
#       <td id="T_4d4fb_row0_col1" class="data row0 col1" >223.4591</td>
# ...

# %% [markdown]
# ## Model Performance using "Normalization" + "Transformation" + "PCA"

# %%
setup(data = dataSets, transformation = True, normalize = True, normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca = True, pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_cadd3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cadd3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cadd3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cadd3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cadd3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cadd3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cadd3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cadd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cadd3_row0_col0" class="data row0 col0" >0.4251</td>
#       <td id="T_cadd3_row0_col1" class="data row0 col1" >200.0175</td>
# ...

# %%
setup(data = dataSets, normalize = True, normalize_method = 'zscore', transformation = True, transformation_method = 'yeo-johnson',pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_6da5e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6da5e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6da5e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6da5e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6da5e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6da5e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6da5e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6da5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6da5e_row0_col0" class="data row0 col0" >0.4462</td>
#       <td id="T_6da5e_row0_col1" class="data row0 col1" >223.4590</td>
# ...

# %%
setup(data = dataSets, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
MeanShiftModel = create_model('meanshift')
MeanShiftPrediction = assign_model(MeanShiftModel)
MeanShiftPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8736" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8736_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b8736_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b8736_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b8736_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b8736_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b8736_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8736_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8736_row0_col0" class="data row0 col0" >0.7633</td>
#       <td id="T_b8736_row0_col1" class="data row0 col1" >762.9648</td>
# ...

# %% [markdown]
# ## Saving the results to csv file

# %%
MeanShiftPrediction.to_csv("MeanShiftResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %% [markdown]
# ## Downloading to Local File System

# %%
from google.colab import files
files.download('MeanShiftResult.csv')

# %% [markdown]
# ##  Save the "trained model"

# %%
x = save_model(MeanShiftModel, 'MeanShiftModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# ## Download the trained model

# %%
from google.colab import files
files.download('MeanShiftModelFile.pkl')

# %% [markdown]
# ## Loading the Model

# %%
MeanShiftModel1 = load_model('MeanShiftModelFile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ## Cluster the new dataset

# %%
newData = get_data("iris").iloc[:10]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
newPredictions = predict_model(MeanShiftModel, data = newData)
newPredictions
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    Cluster
# 0      1.371846     1.504080      1.467106     0.197104  Cluster 1
# 1      1.353089     1.386297      1.467106     0.197104  Cluster 1
# 2      1.333473     1.435087      1.358840     0.197104  Cluster 1
# 3      1.323320     1.410990      1.575792     0.197104  Cluster 1
# 4      1.362570     1.526059      1.467106     0.197104  Cluster 1
# 5      1.398508     1.589238      1.794365     0.389134  Cluster 1
# 6      1.323320     1.481607      1.467106     0.293695  Cluster 1
# 7      1.362570     1.481607      1.575792     0.197104  Cluster 1
# 8      1.302278     1.360979      1.467106     0.197104  Cluster 1
# 9      1.353089     1.410990      1.575792     0.099250  Cluster 1

# %%
newPredictions.to_csv("NewPredictions.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!
